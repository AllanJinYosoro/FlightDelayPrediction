# %%
import sys
sys.path.append('..')

from model.ARIMA import pipline

import pandas as pd

# %%
data = pd.read_csv('../data\scheduled_flight\continuous_flights_data.csv')

# %%
flights=[]
fl=['AA1042','AA1406','AA1486','AA1567','AA167']
for i in fl:
    flights.append(data.loc[data['FLIGHT_ID'] == i])

# %%
flights[0].columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'FLIGHT_ID', 'AIRLINE',
#        'FLIGHT_NUMBER', 'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY', 'ORIGIN_AIRPORT_IATA',
#        'DESTINATION_AIRPORT_IATA', 'Date', 'SD', 'DT', 'WF', 'WN', 'SA', 'AT'],
#       dtype='object')

# %%
P1 = pipline(flights[0],False,True)
P2 = pipline(flights[1],False,True)
P3 = pipline(flights[2],False,True)
P4 = pipline(flights[3],False,True)
P5 = pipline(flights[4],False,True)

piplines = [P1,P2,P3,P4,P5]

# %%
for p in piplines:
    p.fit(False)
    p.summary()
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  292
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                -841.524
# Date:                Mon, 27 May 2024   AIC                           1691.048
# Time:                        19:01:50   BIC                           1705.755
# Sample:                             0   HQIC                          1696.939
#                                 - 292
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      5.7073      0.907      6.295      0.000       3.930       7.484
# ar.L1          0.3505      0.053      6.622      0.000       0.247       0.454
# ar.L2          0.2389      0.055      4.372      0.000       0.132       0.346
# ...

# %%
for p in piplines:
    p.ACF()

# %%
for p in piplines:
    p.UnitSquare(0)
# Out:
# Augmented Dickey-Fuller Test with 0 differencing:
# Test Statistic: -6.8338
# p-value: 0.0000
# Critical Values:
# 	1%: -3.4531
# 	5%: -2.8716
# 	10%: -2.5721
# Reject the null hypothesis. The series is stationary.
# Augmented Dickey-Fuller Test with 0 differencing:
# Test Statistic: -5.9511
# p-value: 0.0000
# Critical Values:
# 	1%: -3.4534
# 	5%: -2.8717
# 	10%: -2.5722
# Reject the null hypothesis. The series is stationary.
# Augmented Dickey-Fuller Test with 0 differencing:
# Test Statistic: -14.2987
# p-value: 0.0000
# Critical Values:
# 	1%: -3.4530
# 	5%: -2.8715
# 	10%: -2.5721
# Reject the null hypothesis. The series is stationary.
# Augmented Dickey-Fuller Test with 0 differencing:
# Test Statistic: -11.3103
# p-value: 0.0000
# Critical Values:
# 	1%: -3.4530
# 	5%: -2.8715
# 	10%: -2.5721
# Reject the null hypothesis. The series is stationary.
# Augmented Dickey-Fuller Test with 0 differencing:
# Test Statistic: -8.7255
# p-value: 0.0000
# Critical Values:
# 	1%: -3.4531
# ...

# %%
for p in piplines:
    p.metrics()
    p.plot()
# Out:
# RMSE: 25.504
# MAE: 16.741
# MAPE: 93.090%
# RMSE: 29.335
# MAE: 22.967
# MAPE: 36172052786900136.000%
# RMSE: 38.060
# MAE: 21.932
# MAPE: 55252821823427144.000%
# RMSE: 54.152
# MAE: 21.239
# MAPE: 152.378%
# RMSE: 22.834
# MAE: 16.134
# MAPE: 57849927290704048.000%
